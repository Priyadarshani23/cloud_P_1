# %%
print("Hello Cloud Computing")
print("This practical is executed using GitHub and Jupyter Notebook")

a = 30
b = 60
print("Sum =", a - b)
# Out:
# Hello Cloud Computing
# This practical is executed using GitHub and Jupyter Notebook
# Sum = -30
